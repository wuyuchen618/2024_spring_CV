# %% [markdown]
# 滑動方框框小矮人藍線範圍 + 貞差法 + HSV

# %%
import os
import cv2
import numpy as np

def detect_blue_stripes(image):
    # Convert to HSV color space
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    
    # Define blue color range in HSV
    lower_blue = np.array([90, 95, 50])
    upper_blue = np.array([150, 255, 255])
    
    # Create a mask for the blue color range
    mask = cv2.inRange(hsv, lower_blue, upper_blue)
    
    # Apply the mask to extract blue regions
    blue_regions = cv2.bitwise_and(image, image, mask=mask)
    
    return blue_regions

def get_blue_line_coordinates(binary_image):
    coordinates = np.column_stack(np.where(binary_image > 0))
    return coordinates

def save_coordinates(coordinates, file_path):
    with open(file_path, 'w') as file:
        for coord in coordinates:
            # Reverse the order to x, y
            file.write(f"{coord[0]}, {coord[1]}\n")
            
def apply_rectangle_mask(image, start_x, start_y, width, height, move_step, index):
    """Apply a mask to keep only the area within the moving rectangle."""
    mask = np.zeros_like(image, dtype=np.uint8)
    move_x = start_x + (index // move_step) * 10  # Calculate the moving x-coordinate of the rectangle
    cv2.rectangle(mask, (move_x, start_y), (move_x + width, start_y + height), (255), thickness=-1)
    return cv2.bitwise_and(image, image, mask=mask)

def process_images(input_folder, output_folder_base, threshold):
    if not os.path.exists(input_folder):
        print(f"Error: Input folder '{input_folder}' does not exist.")
        return

    # Create folders for original and binary results
    output_folder_original_L = output_folder_base + "original_L"
    output_folder_original_R = output_folder_base + "original_R"
    output_folder_binary_L = output_folder_base + "binary_blue_line_result_L"
    output_folder_binary_R = output_folder_base + "binary_blue_line_result_R"
    output_folder_coords_L = output_folder_base + "coords_L"
    output_folder_coords_R = output_folder_base + "coords_R"
    
    # Ensure all folders exist
    for folder in [output_folder_original_L, output_folder_original_R, output_folder_binary_L, output_folder_binary_R, output_folder_coords_L, output_folder_coords_R]:
        os.makedirs(folder, exist_ok=True)
    
    images = [img for img in os.listdir(input_folder) if img.endswith(".jpg")]
    images.sort()  # Ensure images are processed in order
    
    for i, img_name in enumerate(images):
        image_path = os.path.join(input_folder, img_name)
        image = cv2.imread(image_path)

        # Extract blue lines
        blue_regions = detect_blue_stripes(image)
        
        # Convert to grayscale
        gray = cv2.cvtColor(blue_regions, cv2.COLOR_BGR2GRAY)
        
        # Threshold to get binary image
        _, binary_image = cv2.threshold(gray, threshold, 255, cv2.THRESH_BINARY)
        
        # Split image into left and right
        width = image.shape[1]
        left_part = image[:, :width // 2]
        right_part = image[:, width // 2:]
        binary_left = binary_image[:, :width // 2]
        binary_right = binary_image[:, width // 2:]
        
        # Save original left and right images
        cv2.imwrite(os.path.join(output_folder_original_L, f"original_{i:04d}.jpg"), left_part)
        cv2.imwrite(os.path.join(output_folder_original_R, f"original_{i:04d}.jpg"), right_part)

        # Save masked_binary left and right images
        masked_left = apply_rectangle_mask(binary_left, 100, 50, 225, 825, 6, i)
        masked_right = apply_rectangle_mask(binary_right, 200, 0, 150, 890, 7, i)
        cv2.imwrite(os.path.join(output_folder_binary_L, f"binary_{i:04d}.jpg"), masked_left)
        cv2.imwrite(os.path.join(output_folder_binary_R, f"binary_{i:04d}.jpg"), masked_right)

        # Get coordinates of blue lines
        coords_left = get_blue_line_coordinates(masked_left)
        coords_right = get_blue_line_coordinates(masked_right)

        # Save coordinates to text files
        save_coordinates(coords_left, os.path.join(output_folder_coords_L, f"coords_original_{i:04d}.txt"))
        save_coordinates(coords_right, os.path.join(output_folder_coords_R, f"coords_original_{i:04d}.txt"))

input_folder = "./SBS images"  # Actual folder path for images
output_folder_base = "output_images/"  # Base folder path for results
# Check if the folder exists
if not os.path.exists(output_folder_base):
    # If it does not exist, create the folder
    os.makedirs(output_folder_base)
    print(f"Folder {output_folder_base} has been created.")
else:
    print(f"Folder {output_folder_base} already exists.")



threshold = 8  # Threshold for binary image creation

process_images(input_folder, output_folder_base, threshold)
# Out:
# Folder output_images/ has been created.

# %% [markdown]
# 單張epipolor+ RANSAC

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import RANSACRegressor

def compute_epilines(points, which_image, F):
    """计算对极线"""
    if points.shape[0] == 0:
        return None
    lines = cv2.computeCorrespondEpilines(points.reshape(-1, 1, 2), which_image, F)
    return lines.reshape(-1, 3) if lines is not None else None

def find_correspondences(left_pts, right_pts, F, threshold=5):
    """在对极线附近匹配特征点，并使用RANSAC进行进一步筛选"""
    if len(left_pts) == 0 or len(right_pts) == 0:
        return []

    left_pts = np.float32(left_pts)
    right_pts = np.float32(right_pts)

    lines_right = compute_epilines(left_pts, 1, F)
    if lines_right is None:
        print("Error computing epilines for right points.")
        return []

    potential_matches = []
    for i, line in enumerate(lines_right):
        pt1 = left_pts[i]
        distances = np.abs(line[0] * right_pts[:, 0] + line[1] * right_pts[:, 1] + line[2]) / np.sqrt(line[0]**2 + line[1]**2)
        min_dist_idx = np.argmin(distances)
        if distances[min_dist_idx] < threshold:  # 阈值调整
            pt2 = right_pts[min_dist_idx]
            potential_matches.append((pt1, pt2))

    # 使用RANSAC进行进一步筛选
    if len(potential_matches) < 2:
        return []

    src_pts = np.float32([m[0] for m in potential_matches])
    dst_pts = np.float32([m[1] for m in potential_matches])
    ransac = RANSACRegressor()
    ransac.fit(src_pts, dst_pts)
    inlier_mask = ransac.inlier_mask_

    matches = [(src_pts[i], dst_pts[i]) for i in range(len(inlier_mask)) if inlier_mask[i]]
    return matches

def visualize_correspondences_side_by_side(left_img, right_img, matches):
    # Create a combined image by concatenating left and right images side by side
    combined_img = np.concatenate((left_img, right_img), axis=1)

    # Plot the combined image
    plt.figure(figsize=(20, 10))
    plt.imshow(combined_img, cmap='gray')

    # Draw lines connecting the points in the left image to their correspondences in the right image
    for left_pt, right_pt in matches:
        plt.scatter(left_pt[0], left_pt[1], color='red', s=1)  # Smaller point size
        plt.scatter(right_pt[0] + left_img.shape[1], right_pt[1], color='blue', s=1)  # Smaller point size
        plt.plot([left_pt[0], right_pt[0] + left_img.shape[1]], [left_pt[1], right_pt[1]], color='yellow', linewidth=0.1)  # Thinner line

    plt.axis('off')
    plt.show()

def load_coordinates(file_path):
    coords = []
    with open(file_path, 'r') as file:
        for line in file:
            y, x = map(int, line.strip().split(','))  # Note the reversed order
            coords.append([x, y])  # Ensure coordinates are in x, y order
    return np.array(coords)

def draw_epilines_on_right_image(right_img, lines, left_pts):
    """在右图上绘制由左图计算得到的对极线"""
    img_color = cv2.cvtColor(right_img, cv2.COLOR_GRAY2BGR)
    r, c = right_img.shape

    for r, pt in zip(lines, left_pts):
        color = tuple(np.random.randint(0, 255, 3).tolist())
        x0, y0 = map(int, [0, -r[2] / r[1]])
        x1, y1 = map(int, [c, -(r[2] + r[0] * c) / r[1]])
        img_color = cv2.line(img_color, (x0, y0), (x1, y1), color, 1)
        img_color = cv2.circle(img_color, tuple(pt), 5, color, -1)
    return img_color

# Example usage
file_name_index = "0085"
left_img_path = "output_images/original_L/original_" + file_name_index + ".jpg"
right_img_path = "output_images/original_R/original_" + file_name_index + ".jpg"
coords_L_path = "output_images/coords_L/coords_original_" + file_name_index + ".txt"
coords_R_path = "output_images/coords_R/coords_original_" + file_name_index + ".txt"

left_img = cv2.imread(left_img_path, cv2.IMREAD_GRAYSCALE)
right_img = cv2.imread(right_img_path, cv2.IMREAD_GRAYSCALE)

left_pts = load_coordinates(coords_L_path)
right_pts = load_coordinates(coords_R_path)

# Filter out points that are out of bounds for the left image
left_pts = np.array([pt for pt in left_pts if pt[0] < left_img.shape[1] and pt[1] < left_img.shape[0]])
right_pts = np.array([pt for pt in right_pts if pt[0] < right_img.shape[1] and pt[1] < right_img.shape[0]])

# Fundamental Matrix (example values, you should replace these with your actual fundamental matrix)
F = np.array([[3.283965767647195E-7, -6.76098398189792E-6, 0.0021123144539793737],
              [-8.046341661808292E-6, 3.05632173594769E-8, 0.05124913199417346],
              [0.0048160232373805345, -0.051062699158041805, 1.0706286680443888]])

# Compute epilines for left points and draw them on right image
lines_right = compute_epilines(left_pts, 1, F)
right_img_lines = draw_epilines_on_right_image(right_img, lines_right, left_pts)

matches = find_correspondences(left_pts, right_pts, F)
print("Matches: ", matches)

visualize_correspondences_side_by_side(left_img, right_img, matches)

# Display the right image with epilines
plt.figure(figsize=(10, 10))
plt.imshow(right_img_lines)
plt.axis('off')
plt.show()
# Out:
# Matches:  [(array([333., 282.], dtype=float32), array([381., 239.], dtype=float32)), (array([334., 282.], dtype=float32), array([381., 239.], dtype=float32)), (array([333., 283.], dtype=float32), array([381., 240.], dtype=float32)), (array([332., 284.], dtype=float32), array([381., 241.], dtype=float32)), (array([333., 284.], dtype=float32), array([381., 241.], dtype=float32)), (array([332., 285.], dtype=float32), array([381., 242.], dtype=float32)), (array([333., 285.], dtype=float32), array([381., 242.], dtype=float32)), (array([332., 286.], dtype=float32), array([381., 243.], dtype=float32)), (array([333., 286.], dtype=float32), array([381., 243.], dtype=float32)), (array([332., 287.], dtype=float32), array([381., 244.], dtype=float32)), (array([331., 288.], dtype=float32), array([380., 247.], dtype=float32)), (array([331., 289.], dtype=float32), array([380., 247.], dtype=float32)), (array([330., 290.], dtype=float32), array([380., 248.], dtype=float32)), (array([331., 290.], dtype=float32), array([380., 248.], dtype=float32)), (array([330., 291.], dtype=float32), array([380., 249.], dtype=float32)), (array([331., 291.], dtype=float32), array([380., 249.], dtype=float32)), (array([330., 292.], dtype=float32), array([380., 250.], dtype=float32)), (array([330., 293.], dtype=float32), array([380., 251.], dtype=float32)), (array([330., 294.], dtype=float32), array([380., 252.], dtype=float32)), (array([330., 295.], dtype=float32), array([380., 253.], dtype=float32)), (array([331., 301.], dtype=float32), array([380., 260.], dtype=float32)), (array([331., 302.], dtype=float32), array([381., 261.], dtype=float32)), (array([332., 303.], dtype=float32), array([381., 262.], dtype=float32)), (array([332., 304.], dtype=float32), array([381., 263.], dtype=float32)), (array([333., 304.], dtype=float32), array([381., 263.], dtype=float32)), (array([332., 305.], dtype=float32), array([381., 264.], dtype=float32)), (array([333., 305.], dtype=float32), array([381., 264.], dtype=float32)), (array([333., 306.], dtype=float32), array([381., 265.], dtype=float32)), (array([333., 307.], dtype=float32), array([381., 266.], dtype=float32)), (array([333., 308.], dtype=float32), array([380., 268.], dtype=float32)), (array([333., 309.], dtype=float32), array([381., 269.], dtype=float32)), (array([333., 310.], dtype=float32), array([381., 270.], dtype=float32)), (array([333., 311.], dtype=float32), array([381., 271.], dtype=float32)), (array([334., 311.], dtype=float32), array([381., 271.], dtype=float32)), (array([334., 312.], dtype=float32), array([381., 272.], dtype=float32)), (array([334., 313.], dtype=float32), array([382., 273.], dtype=float32)), (array([334., 314.], dtype=float32), array([382., 274.], dtype=float32)), (array([334., 315.], dtype=float32), array([382., 275.], dtype=float32)), (array([335., 315.], dtype=float32), array([382., 275.], dtype=float32)), (array([334., 316.], dtype=float32), array([382., 276.], dtype=float32)), (array([335., 316.], dtype=float32), array([382., 276.], dtype=float32)), (array([334., 317.], dtype=float32), array([382., 277.], dtype=float32)), (array([335., 317.], dtype=float32), array([382., 277.], dtype=float32)), (array([334., 318.], dtype=float32), array([381., 279.], dtype=float32)), (array([335., 318.], dtype=float32), array([381., 279.], dtype=float32)), (array([334., 319.], dtype=float32), array([381., 280.], dtype=float32)), (array([335., 319.], dtype=float32), array([381., 280.], dtype=float32)), (array([335., 320.], dtype=float32), array([381., 281.], dtype=float32)), (array([335., 321.], dtype=float32), array([381., 282.], dtype=float32)), (array([335., 322.], dtype=float32), array([382., 283.], dtype=float32)), (array([354., 337.], dtype=float32), array([392., 299.], dtype=float32)), (array([354., 338.], dtype=float32), array([392., 300.], dtype=float32)), (array([356., 340.], dtype=float32), array([393., 302.], dtype=float32)), (array([356., 341.], dtype=float32), array([393., 303.], dtype=floa ...

# %% [markdown]
# 不儲epipolor line照片  遍歷版把所有matchimg poits 存到TXT

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import RANSACRegressor

def compute_epilines(points, which_image, F):
    """计算对极线"""
    if points.shape[0] == 0:
        return None
    lines = cv2.computeCorrespondEpilines(points.reshape(-1, 1, 2), which_image, F)
    return lines.reshape(-1, 3) if lines is not None else None

def find_correspondences(left_pts, right_pts, F, threshold=5):
    """在对极线附近匹配特征点，并使用RANSAC进行进一步筛选"""
    if len(left_pts) == 0 or len(right_pts) == 0:
        return []

    left_pts = np.float32(left_pts)
    right_pts = np.float32(right_pts)

    lines_right = compute_epilines(left_pts, 1, F)
    if lines_right is None:
        print("Error computing epilines for right points.")
        return []

    potential_matches = []
    for i, line in enumerate(lines_right):
        pt1 = left_pts[i]
        distances = np.abs(line[0] * right_pts[:, 0] + line[1] * right_pts[:, 1] + line[2]) / np.sqrt(line[0]**2 + line[1]**2)
        min_dist_idx = np.argmin(distances)
        if distances[min_dist_idx] < threshold:  # 阈值调整
            pt2 = right_pts[min_dist_idx]
            potential_matches.append((pt1, pt2))

    # 使用RANSAC进行进一步筛选
    if len(potential_matches) < 2:
        return []

    src_pts = np.float32([m[0] for m in potential_matches])
    dst_pts = np.float32([m[1] for m in potential_matches])
    ransac = RANSACRegressor()
    ransac.fit(src_pts, dst_pts)
    inlier_mask = ransac.inlier_mask_

    matches = [(src_pts[i], dst_pts[i]) for i in range(len(inlier_mask)) if inlier_mask[i]]
    return matches

def visualize_correspondences_side_by_side(left_img, right_img, matches, save_path):
    # Create a combined image by concatenating left and right images side by side
    combined_img = np.concatenate((left_img, right_img), axis=1)

    # Plot the combined image
    plt.figure(figsize=(20, 10))
    plt.imshow(combined_img, cmap='gray')

    # Draw lines connecting the points in the left image to their correspondences in the right image
    for left_pt, right_pt in matches:
        plt.scatter(left_pt[0], left_pt[1], color='red', s=1)  # Smaller point size
        plt.scatter(right_pt[0] + left_img.shape[1], right_pt[1], color='blue', s=1)  # Smaller point size
        plt.plot([left_pt[0], right_pt[0] + left_img.shape[1]], [left_pt[1], right_pt[1]], color='yellow', linewidth=0.1)  # Thinner line

    plt.axis('off')
    plt.savefig(save_path, bbox_inches='tight')
    plt.close()

def load_coordinates(file_path):
    coords = []
    with open(file_path, 'r') as file:
        for line in file:
            y, x = map(int, line.strip().split(','))  # Note the reversed order
            coords.append([x, y])  # Ensure coordinates are in x, y order
    return np.array(coords)

def draw_epilines_on_right_image(right_img, lines, left_pts):
    """在右图上绘制由左图计算得到的对极线"""
    img_color = cv2.cvtColor(right_img, cv2.COLOR_GRAY2BGR)
    r, c = right_img.shape

    for r, pt in zip(lines, left_pts):
        color = tuple(np.random.randint(0, 255, 3).tolist())
        x0, y0 = map(int, [0, -r[2] / r[1]])
        x1, y1 = map(int, [c, -(r[2] + r[0] * c) / r[1]])
        img_color = cv2.line(img_color, (x0, y0), (x1, y1), color, 1)
        img_color = cv2.circle(img_color, tuple(pt), 5, color, -1)
    return img_color

def save_matches(matches, file_path):
    """保存匹配的坐标点对到TXT文件"""
    with open(file_path, 'w') as file:
        for pt1, pt2 in matches:
            file.write(f"{int(pt1[0])},{int(pt1[1])},{int(pt2[0])},{int(pt2[1])}\n")
    print(f"Saved matches to {file_path}")

# 指定路径
left_img_dir = 'output_images/original_L'
right_img_dir = 'output_images/original_R'
coords_L_dir = 'output_images/coords_L'
coords_R_dir = 'output_images/coords_R'
output_vis_dir = 'output_images/visualized_correspondences'
output_matches_dir = 'output_images/matches'

# 创建输出目录
os.makedirs(output_vis_dir, exist_ok=True)
os.makedirs(output_matches_dir, exist_ok=True)

# Fundamental Matrix (example values, you should replace these with your actual fundamental matrix)
F = np.array([[3.283965767647195E-7, -6.76098398189792E-6, 0.0021123144539793737],
              [-8.046341661808292E-6, 3.05632173594769E-8, 0.05124913199417346],
              [0.0048160232373805345, -0.051062699158041805, 1.0706286680443888]])

# 获取并排序文件名
left_files = sorted(os.listdir(left_img_dir))
right_files = sorted(os.listdir(right_img_dir))
coords_L_files = sorted(os.listdir(coords_L_dir))
coords_R_files = sorted(os.listdir(coords_R_dir))

# 确保文件名列表的长度一致
assert len(left_files) == len(right_files) == len(coords_L_files) == len(coords_R_files)

# 遍历所有输入文件
for index, (left_file, right_file, coords_L_file, coords_R_file) in enumerate(zip(left_files, right_files, coords_L_files, coords_R_files)):
    if left_file.endswith('.jpg') and right_file.endswith('.jpg') and coords_L_file.endswith('.txt') and coords_R_file.endswith('.txt'):
        left_img_path = os.path.join(left_img_dir, left_file)
        right_img_path = os.path.join(right_img_dir, right_file)
        coords_L_path = os.path.join(coords_L_dir, coords_L_file)
        coords_R_path = os.path.join(coords_R_dir, coords_R_file)
        output_vis_path = os.path.join(output_vis_dir, f'{index:04d}_visualization.jpg')
        output_matches_path = os.path.join(output_matches_dir, f'{index:04d}_matches.txt')

        # 读取图像和坐标
        left_img = cv2.imread(left_img_path, cv2.IMREAD_GRAYSCALE)
        right_img = cv2.imread(right_img_path, cv2.IMREAD_GRAYSCALE)
        left_pts = load_coordinates(coords_L_path)
        right_pts = load_coordinates(coords_R_path)

        # 检查坐标点是否加载正确
        if len(left_pts) == 0:
            print(f"No points found in {coords_L_path}")
            continue
        if len(right_pts) == 0:
            print(f"No points found in {coords_R_path}")
            continue

        # 过滤图像边界外的点
        left_pts = np.array([pt for pt in left_pts if pt[0] < left_img.shape[1] and pt[1] < left_img.shape[0]])
        right_pts = np.array([pt for pt in right_pts if pt[0] < right_img.shape[1] and pt[1] < right_img.shape[0]])

        # 计算对极线并绘制在右图上
        lines_right = compute_epilines(left_pts, 1, F)
        right_img_lines = draw_epilines_on_right_image(right_img, lines_right, left_pts)

        # 找到匹配点
        matches = find_correspondences(left_pts, right_pts, F)
        print(f"Number of epipolar matches for {left_file}: {len(matches)}")

        # 保存匹配点对到TXT文件
        save_matches(matches, output_matches_path)

        # 可视化并保存匹配点
        # save epipolor line visualize matching points 
        # visualize_correspondences_side_by_side(left_img, right_img, matches, output_vis_path)
# Out:
# Number of epipolar matches for original_0000.jpg: 117
# Saved matches to output_images/matches\0000_matches.txt
# Number of epipolar matches for original_0001.jpg: 219
# Saved matches to output_images/matches\0001_matches.txt
# Number of epipolar matches for original_0002.jpg: 355
# Saved matches to output_images/matches\0002_matches.txt
# Number of epipolar matches for original_0003.jpg: 534
# Saved matches to output_images/matches\0003_matches.txt
# Number of epipolar matches for original_0004.jpg: 637
# Saved matches to output_images/matches\0004_matches.txt
# Number of epipolar matches for original_0005.jpg: 696
# Saved matches to output_images/matches\0005_matches.txt
# Number of epipolar matches for original_0006.jpg: 778
# Saved matches to output_images/matches\0006_matches.txt
# Number of epipolar matches for original_0007.jpg: 893
# Saved matches to output_images/matches\0007_matches.txt
# Number of epipolar matches for original_0008.jpg: 1017
# Saved matches to output_images/matches\0008_matches.txt
# Number of epipolar matches for original_0009.jpg: 1077
# Saved matches to output_images/matches\0009_matches.txt
# Number of epipolar matches for original_0010.jpg: 1143
# Saved matches to output_images/matches\0010_matches.txt
# Number of epipolar matches for original_0011.jpg: 1190
# Saved matches to output_images/matches\0011_matches.txt
# Number of epipolar matches for original_0012.jpg: 1187
# Saved matches to output_images/matches\0012_matches.txt
# Number of epipolar matches for original_0013.jpg: 1288
# Saved matches to output_images/matches\0013_matches.txt
# Number of epipolar matches for original_0014.jpg: 1357
# Saved matches to output_images/matches\0014_matches.txt
# Number of epipolar matches for original_0015.jpg: 1376
# Saved matches to output_images/matches\0015_matches.txt
# Number of epipolar matches for original_0016.jpg: 1412
# Saved matches to output_images/matches\0016_matches.txt
# Number of epipolar matches for original_0017.jpg: 1330
# Saved matches to output_images/matches\0017_matches.txt
# Number of epipolar matches for original_0018.jpg: 1140
# Saved matches to output_images/matches\0018_matches.txt
# Number of epipolar matches for original_0019.jpg: 1040
# Saved matches to output_images/matches\0019_matches.txt
# Number of epipolar matches for original_0020.jpg: 1314
# Saved matches to output_images/matches\0020_matches.txt
# Number of epipolar matches for original_0021.jpg: 1419
# Saved matches to output_images/matches\0021_matches.txt
# Number of epipolar matches for original_0022.jpg: 1409
# Saved matches to output_images/matches\0022_matches.txt
# Number of epipolar matches for original_0023.jpg: 1418
# Saved matches to output_images/matches\0023_matches.txt
# Number of epipolar matches for original_0024.jpg: 1451
# Saved matches to output_images/matches\0024_matches.txt
# Number of epipolar matches for original_0025.jpg: 1484
# Saved matches to output_images/matches\0025_matches.txt
# Number of epipolar matches for original_0026.jpg: 1572
# Saved matches to output_images/matches\0026_matches.txt
# Number of epipolar matches for original_0027.jpg: 1554
# Saved matches to output_images/matches\0027_matches.txt
# Number of epipolar matches for original_0028.jpg: 1586
# Saved matches to output_images/matches\0028_matches.txt
# Number of epipolar matches for original_0029.jpg: 1573
# Saved matches to output_images/matches\0029_matches.txt
# Number of epipolar matches for original_0030.jpg: 1582
# Saved matches to output_images/matches\0030_matches.txt
# Number of epipolar matches for original_0031.jpg: 1588
# Saved matches to output_images/matches\0031_matches.txt
# Number of epipolar matches for original_0032.jpg: 1580
# Saved matches to output_images/matches\0032_matches.txt
# Number of epipolar matches for original_0033.jpg: 1528
# Saved matches to output_images/matches\0033_matches.txt
# Number of epipolar matches for original_0034.jpg: 1514
# Saved matches to output_images/matches\0034_matches.txt
# Number of epipolar matches for original_0035.jpg: 1485
# Saved matches to output_images/matches\0035_matches.txt
# Number of epipolar matches for original_0036.jpg: 1489
# Saved matches to output_images/matches\0036_matches.txt
# Number of epipolar matches for original_0037.jpg: 1509
# Saved matches to output_images/matches\0037_matches.txt
# Number of epipolar matches for original_0038.jpg: 1520
# Saved matches to output_images/matches\0038_matches.txt
# Number of epipolar matches for original_0039.jpg: 1459
# Saved matches to output_images/matches\0039_matches.txt
# Number of epipolar matches for original_0040.jpg: 1388
# Saved matches to output_images/matches\0040_matches.txt
# Number of epipolar matches for original_0041.jpg: 1423
# Saved matches to output_images/matches\0041_matches.txt
# Number of epipolar matches for original_0042.jpg: 1412
# Saved matches to output_images/matches\0042_matches.txt
# Number of epipolar matches for original_0043.jpg: 1477
# Saved matches to output_images/matches\0043_matches.txt
# Number of epipolar matches for original_0044.jpg: 1455
# Saved matches to output_images/matches\0044_matches.txt
# Number of epipolar matches for original_0045.jpg: 1345
# Saved matches to output_images/matches\0045_matches.txt
# Number of epipolar matches for original_0046.jpg: 1346
# Saved matches to output_images/matches\0046_matches.txt
# Number of epipolar matches for original_0047.jpg: 1300
# Saved matches to output_images/matches\0047_matches.txt
# Number of epipolar matches for original_0048.jpg: 1258
# Saved matches to output_images/matches\0048_matches.txt
# Number of epipolar matches for original_0049.jpg: 1307
# Saved matches to output_images/matches\0049_matches.txt
# Number of epipolar matches for original_0050.jpg: 1252
# Saved matches to output_images/matches\0050_matches.txt
# Number of epipolar matches for original_0051.jpg: 1224
# Saved matches to output_images/matches\0051_matches.txt
# Number of epipolar matches for original_0052.jpg: 1296
# Saved matches to output_images/matches\0052_matches.txt
# Number of epipolar matches for original_0053.jpg: 1330
# Saved matches to output_images/matches\0053_matches.txt
# Number of epipolar matches for original_0054.jpg: 1276
# Saved matches to output_images/matches\0054_matches.txt
# Number of epipolar matches for original_0055.jpg: 1291
# Saved matches to output_images/matches\0055_matches.txt
# Number of epipolar matches for original_0056.jpg: 1301
# Saved matches to output_images/matches\0056_matches.txt
# Number of epipolar matches for original_0057.jpg: 1293
# Saved matches to output_images/matches\0057_matches.txt
# Number of epipolar matches for original_0058.jpg: 1254
# Saved matches to output_images/matches\0058_matches.txt
# Number of epipolar matches for original_0059.jpg: 1190
# Saved matches to output_images/matches\0059_matches.txt
# Number of epipolar matches for original_0060.jpg: 1186
# Saved matches to output_images/matches\0060_matches.txt
# Number of epipolar matches for original_0061.jpg: 1230
# Saved matches to output_images/matches\0061_matches.txt
# Number of epipolar matches for original_0062.jpg: 1181
# Saved matches to output_images/matches\0062_matches.txt
# Number of epipolar matches for original_0063.jpg: 1216
# Saved matches to output_images/matches\0063_matches.txt
# Number of epipolar matches for original_0064.jpg: 1138
# Saved matches to output_images/matches\0064_matches.txt
# Number of epipolar matches for original_0065.jpg: 1005
# Saved matches to output_images/matches\0065_matches.txt
# Number of epipolar matches for original_0066.jpg: 1056
# Saved matches to output_images/matches\0066_matches.txt
# Number of epipolar matches for original_0067.jpg: 1003
# Saved matches to output_images/matches\0067_matches.txt
# Number of epipolar matches for original_0068.jpg: 893
# Saved matches to output_images/matches\0068_matches.txt
# Number of epipolar matches for original_0069.jpg: 719
# Saved matches to output_images/matches\0069_matches.txt
# Number of epipolar matches for original_0070.jpg: 649
# Saved matches to output_images/matches\0070_matches.txt
# Number of epipolar matches for original_0071.jpg: 734
# Saved matches to output_images/matches\0071_matches.txt
# Number of epipolar matches for original_0072.jpg: 744
# Saved matches to output_images/matches\0072_matches.txt
# Number of epipolar matches for original_0073.jpg: 768
# Saved matches to output_images/matches\0073_matches.txt
# Number of epipolar matches for original_0074.jpg: 812
# Saved matches to output_images/matches\0074_matches.txt
# Number of epipolar matches for original_0075.jpg: 904
# Saved matches to output_images/matches\0075_matches.txt
# Number of epipolar matches for original_0076.jpg: 983
# Saved matches to output_images/matches\0076_matches.txt
# Number of epipolar matches for original_0077.jpg: 980
# Saved matches to output_images/matches\0077_matches.txt
# Number of epipolar matches for original_0078.jpg: 947
# Saved matches to output_images/matches\0078_matches.txt
# Number of epipolar matches for original_0079.jpg: 1159
# Saved matches to output_images/matches\0079_matches.txt
# Number of epipolar matches for original_0080.jpg: 1250
# Saved matches to output_images/matches\0080_matches.txt
# Number of epipolar matches for original_0081.jpg: 1325
# Saved matches to output_images/matches\0081_matches.txt
# Number of epipolar matches for original_0082.jpg: 1441
# Saved matches to output_images/matches\0082_matches.txt
# Number of epipolar matches for original_0083.jpg: 1297
# Saved matches to output_images/matches\0083_matches.txt
# Number of epipolar matches for original_0084.jpg: 1358
# Saved matches to output_images/matches\0084_matches.txt
# Number of epipolar matches for original_0085.jpg: 1322
# Saved matches to output_images/matches\0085_matches.txt
# Number of epipolar matches for original_0086.jpg: 1248
# Saved matches to output_images/matches\0086_matches.txt
# Number of epipolar matches for original_0087.jpg: 1234
# Saved matches to output_images/matches\0087_matches.txt
# Number of epipolar matches for original_0088.jpg: 1145
# Saved matches to output_images/matches\0088_matches.txt
# Number of epipolar matches for original_0089.jpg: 1077
# Saved matches to output_images/matches\0089_matches.txt
# Number of epipolar matches for original_0090.jpg: 957
# Saved matches to output_images/matches\0090_matches.txt
# Number of epipolar matches for original_0091.jpg: 948
# Saved matches to output_images/matches\0091_matches.txt
# Number of epipolar matches for original_0092.jpg: 848
# Saved matches to output_images/matches\0092_matches.txt
# Number of epipolar matches for original_0093.jpg: 744
# Saved matches to output_images/matches\0093_matches.txt
# Number of epipolar matches for original_0094.jpg: 742
# Saved matches to output_images/matches\0094_matches.txt
# Number of epipolar matches for original_0095.jpg: 667
# Saved matches to output_images/matches\0095_matches.txt
# Number of epipolar matches for original_0096.jpg: 679
# Saved matches to output_images/matches\0096_matches.txt
# Number of epipolar matches for original_0097.jpg: 681
# Saved matches to output_images/matches\0097_matches.txt
# Number of epipolar matches for original_0098.jpg: 663
# Saved matches to output_images/matches\0098_matches.txt
# Number of epipolar matches for original_0099.jpg: 662
# Saved matches to output_images/matches\0099_matches.txt
# Number of epipolar matches for original_0100.jpg: 643
# Saved matches to output_images/matches\0100_matches.txt
# Number of epipolar matches for original_0101.jpg: 579
# Saved matches to output_images/matches\0101_matches.txt
# Number of epipolar matches for original_0102.jpg: 509
# Saved matches to output_images/matches\0102_matches.txt
# Number of epipolar matches for original_0103.jpg: 502
# Saved matches to output_images/matches\0103_matches.txt
# Number of epipolar matches for original_0104.jpg: 605
# Saved matches to output_images/matches\0104_matches.txt
# Number of epipolar matches for original_0105.jpg: 680
# Saved matches to output_images/matches\0105_matches.txt
# Number of epipolar matches for original_0106.jpg: 665
# Saved matches to output_images/matches\0106_matches.txt
# Number of epipolar matches for original_0107.jpg: 619
# Saved matches to output_images/matches\0107_matches.txt
# Number of epipolar matches for original_0108.jpg: 597
# Saved matches to output_images/matches\0108_matches.txt
# Number of epipolar matches for original_0109.jpg: 615
# Saved matches to output_images/matches\0109_matches.txt
# Number of epipolar matches for original_0110.jpg: 676
# Saved matches to output_images/matches\0110_matches.txt
# Number of epipolar matches for original_0111.jpg: 663
# Saved matches to output_images/matches\0111_matches.txt
# Number of epipolar matches for original_0112.jpg: 619
# Saved matches to output_images/matches\0112_matches.txt
# Number of epipolar matches for original_0113.jpg: 657
# Saved matches to output_images/matches\0113_matches.txt
# Number of epipolar matches for original_0114.jpg: 650
# Saved matches to output_images/matches\0114_matches.txt
# Number of epipolar matches for original_0115.jpg: 640
# Saved matches to output_images/matches\0115_matches.txt
# Number of epipolar matches for original_0116.jpg: 726
# Saved matches to output_images/matches\0116_matches.txt
# Number of epipolar matches for original_0117.jpg: 685
# Saved matches to output_images/matches\0117_matches.txt
# Number of epipolar matches for original_0118.jpg: 573
# Saved matches to output_images/matches\0118_matches.txt
# Number of epipolar matches for original_0119.jpg: 451
# Saved matches to output_images/matches\0119_matches.txt
# Number of epipolar matches for original_0120.jpg: 427
# Saved matches to output_images/matches\0120_matches.txt
# Number of epipolar matches for original_0121.jpg: 374
# Saved matches to output_images/matches\0121_matches.txt
# Number of epipolar matches for original_0122.jpg: 397
# Saved matches to output_images/matches\0122_matches.txt
# Number of epipolar matches for original_0123.jpg: 423
# Saved matches to output_images/matches\0123_matches.txt
# Number of epipolar matches for original_0124.jpg: 458
# Saved matches to output_images/matches\0124_matches.txt
# Number of epipolar matches for original_0125.jpg: 391
# Saved matches to output_images/matches\0125_matches.txt
# Number of epipolar matches for original_0126.jpg: 373
# Saved matches to output_images/matches\0126_matches.txt
# Number of epipolar matches for original_0127.jpg: 319
# Saved matches to output_images/matches\0127_matches.txt
# Number of epipolar matches for original_0128.jpg: 321
# Saved matches to output_images/matches\0128_matches.txt
# Number of epipolar matches for original_0129.jpg: 354
# Saved matches to output_images/matches\0129_matches.txt
# Number of epipolar matches for original_0130.jpg: 346
# Saved matches to output_images/matches\0130_matches.txt
# Number of epipolar matches for original_0131.jpg: 351
# Saved matches to output_images/matches\0131_matches.txt
# Number of epipolar matches for original_0132.jpg: 327
# Saved matches to output_images/matches\0132_matches.txt
# Number of epipolar matches for original_0133.jpg: 342
# Saved matches to output_images/matches\0133_matches.txt
# Number of epipolar matches for original_0134.jpg: 336
# Saved matches to output_images/matches\0134_matches.txt
# Number of epipolar matches for original_0135.jpg: 360
# Saved matches to output_images/matches\0135_matches.txt
# Number of epipolar matches for original_0136.jpg: 386
# Saved matches to output_images/matches\0136_matches.txt
# Number of epipolar matches for original_0137.jpg: 399
# Saved matches to output_images/matches\0137_matches.txt
# Number of epipolar matches for original_0138.jpg: 405
# Saved matches to output_images/matches\0138_matches.txt
# Number of epipolar matches for original_0139.jpg: 432
# Saved matches to output_images/matches\0139_matches.txt
# Number of epipolar matches for original_0140.jpg: 464
# Saved matches to output_images/matches\0140_matches.txt
# Number of epipolar matches for original_0141.jpg: 473
# Saved matches to output_images/matches\0141_matches.txt
# Number of epipolar matches for original_0142.jpg: 495
# Saved matches to output_images/matches\0142_matches.txt
# Number of epipolar matches for original_0143.jpg: 524
# Saved matches to output_images/matches\0143_matches.txt
# Number of epipolar matches for original_0144.jpg: 500
# Saved matches to output_images/matches\0144_matches.txt
# Number of epipolar matches for original_0145.jpg: 524
# Saved matches to output_images/matches\0145_matches.txt
# Number of epipolar matches for original_0146.jpg: 500
# Saved matches to output_images/matches\0146_matches.txt
# Number of epipolar matches for original_0147.jpg: 469
# Saved matches to output_images/matches\0147_matches.txt
# Number of epipolar matches for original_0148.jpg: 458
# Saved matches to output_images/matches\0148_matches.txt
# Number of epipolar matches for original_0149.jpg: 457
# Saved matches to output_images/matches\0149_matches.txt
# Number of epipolar matches for original_0150.jpg: 463
# Saved matches to output_images/matches\0150_matches.txt
# Number of epipolar matches for original_0151.jpg: 472
# Saved matches to output_images/matches\0151_matches.txt
# Number of epipolar matches for original_0152.jpg: 438
# Saved matches to output_images/matches\0152_matches.txt
# Number of epipolar matches for original_0153.jpg: 383
# Saved matches to output_images/matches\0153_matches.txt
# Number of epipolar matches for original_0154.jpg: 275
# Saved matches to output_images/matches\0154_matches.txt
# Number of epipolar matches for original_0155.jpg: 171
# Saved matches to output_images/matches\0155_matches.txt
# Number of epipolar matches for original_0156.jpg: 154
# Saved matches to output_images/matches\0156_matches.txt
# Number of epipolar matches for original_0157.jpg: 128
# Saved matches to output_images/matches\0157_matches.txt
# Number of epipolar matches for original_0158.jpg: 123
# Saved matches to output_images/matches\0158_matches.txt
# Number of epipolar matches for original_0159.jpg: 98
# Saved matches to output_images/matches\0159_matches.txt
# Number of epipolar matches for original_0160.jpg: 89
# Saved matches to output_images/matches\0160_matches.txt
# Number of epipolar matches for original_0161.jpg: 70
# Saved matches to output_images/matches\0161_matches.txt
# Number of epipolar matches for original_0162.jpg: 56
# Saved matches to output_images/matches\0162_matches.txt
# Number of epipolar matches for original_0163.jpg: 71
# Saved matches to output_images/matches\0163_matches.txt
# Number of epipolar matches for original_0164.jpg: 72
# Saved matches to output_images/matches\0164_matches.txt
# Number of epipolar matches for original_0165.jpg: 68
# Saved matches to output_images/matches\0165_matches.txt
# Number of epipolar matches for original_0166.jpg: 64
# Saved matches to output_images/matches\0166_matches.txt
# Number of epipolar matches for original_0167.jpg: 62
# Saved matches to output_images/matches\0167_matches.txt
# Number of epipolar matches for original_0168.jpg: 48
# Saved matches to output_images/matches\0168_matches.txt
# Number of epipolar matches for original_0169.jpg: 52
# Saved matches to output_images/matches\0169_matches.txt
# Number of epipolar matches for original_0170.jpg: 49
# Saved matches to output_images/matches\0170_matches.txt
# Number of epipolar matches for original_0171.jpg: 43
# Saved matches to output_images/matches\0171_matches.txt
# Number of epipolar matches for original_0172.jpg: 39
# Saved matches to output_images/matches\0172_matches.txt
# Number of epipolar matches for original_0173.jpg: 35
# Saved matches to output_images/matches\0173_matches.txt
# Number of epipolar matches for original_0174.jpg: 27
# Saved matches to output_images/matches\0174_matches.txt
# Number of epipolar matches for original_0175.jpg: 18
# Saved matches to output_images/matches\0175_matches.txt
# Number of epipolar matches for original_0176.jpg: 13
# Saved matches to output_images/matches\0176_matches.txt
# Number of epipolar matches for original_0177.jpg: 5
# Saved matches to output_images/matches\0177_matches.txt
# No points found in output_images/coords_L\coords_original_0178.txt

# %% [markdown]
# 3D 點雲上色

# %%
import os
import numpy as np
import cv2
from PIL import Image

def reconstruct_3d_points(matches, K_left, RT_left, K_right, RT_right):
    """通过匹配点对和相机参数重建3D点"""
    P_left = K_left @ RT_left
    P_right = K_right @ RT_right

    pts1 = np.array([[x1, y1] for (x1, y1, x2, y2) in matches], dtype=np.float32).T
    pts2 = np.array([[x2, y2] for (x1, y1, x2, y2) in matches], dtype=np.float32).T

    # 检查pts1和pts2的形状
    print(f"Shape of pts1: {pts1.shape}")
    print(f"Shape of pts2: {pts2.shape}")

    points_4d_hom = cv2.triangulatePoints(P_left, P_right, pts1, pts2)
    points_3d = points_4d_hom[:3] / points_4d_hom[3]

    return points_3d.T

def save_3d_points(points_3d, colors, file_path):
    """保存3D点和颜色到XYZ文件"""
    with open(file_path, 'w') as file:
        for pt, color in zip(points_3d, colors):
            file.write(f"{pt[0]:.6f} {pt[1]:.6f} {pt[2]:.6f} {color[0]} {color[1]} {color[2]}\n")
    print(f"保存3D点到 {file_path}")

def load_matches(file_path):
    """从文件中加载匹配点对"""
    matches = []
    with open(file_path, 'r') as file:
        for line in file:
            if line.strip():
                x1, y1, x2, y2 = map(int, line.strip().split(','))
                matches.append((x1, y1, x2, y2))
    return matches

def get_color_from_image(image, x, y):
    """从图像中获取指定点的颜色"""
    if 0 <= x < image.width and 0 <= y < image.height:
        return image.getpixel((int(x), int(y)))
    return (0, 0, 0)  # 默認黑色，如果超出範圍

# 相机内参矩阵
K_left = np.array([[1000.0, 0.0, 360.0],
                   [0.0, 1000.0, 640.0],
                   [0.0, 0.0, 1.0]])

RT_left = np.array([[0.88649035, -0.46274707, -0.00, -14.42428],
                    [-0.070794605, -0.13562201, -0.98822814, 86.532959],
                    [0.45729965, 0.8760547, -0.1529876, 235.35446]])

K_right = np.array([[1100.0, 0.0, 360.0],
                    [0.0, 1100.0, 640.0],
                    [0.0, 0.0, 1.0]])

RT_right = np.array([[0.98480779, -0.17364818, -4.9342116E-8, -0.98420829],
                     [-0.026566068, -0.15066338, -0.98822814, 85.070221],
                     [0.17160401, 0.97321475, -0.1529876, 236.97873]])

# 指定路径和载入影像
matches_dir = 'output_images/matches/'
output_3d_path = 'M11202130_stanta_colored_3d_points.txt'
left_image_path = './output_images/original_L/original_0000.jpg'
right_image_path = './output_images/original_R/original_0000.jpg'

left_image = Image.open(left_image_path)
right_image = Image.open(right_image_path)

# 创建保存所有3D点的文件
with open(output_3d_path, 'w') as output_file:
    # 遍历匹配点对文件
    for file_name in os.listdir(matches_dir):
        if file_name.endswith('_matches.txt'):
            matches_file_path = os.path.join(matches_dir, file_name)

            # 加载匹配点对
            matches = load_matches(matches_file_path)

            # 通过匹配点对重建3D点
            if len(matches) > 0:
                points_3d = reconstruct_3d_points(matches, K_left, RT_left, K_right, RT_right)

                # 提取颜色并保存3D点到单一XYZ文件
                if points_3d.size > 0:
                    colors = [get_color_from_image(left_image, x1, y1) for (x1, y1, x2, y2) in matches]
                    for pt, color in zip(points_3d, colors):
                        output_file.write(f"{pt[0]:.6f} {pt[1]:.6f} {pt[2]:.6f} {color[0]} {color[1]} {color[2]}\n")
                else:
                    print(f"Failed to reconstruct 3D points for {file_name}")
            else:
                print(f"No matches to reconstruct 3D points for {file_name}")

print(f"Saved all 3D points to {output_3d_path}")
# Out:
# Shape of pts1: (2, 117)
# Shape of pts2: (2, 117)
# Shape of pts1: (2, 219)
# Shape of pts2: (2, 219)
# Shape of pts1: (2, 355)
# Shape of pts2: (2, 355)
# Shape of pts1: (2, 534)
# Shape of pts2: (2, 534)
# Shape of pts1: (2, 637)
# Shape of pts2: (2, 637)
# Shape of pts1: (2, 696)
# Shape of pts2: (2, 696)
# Shape of pts1: (2, 778)
# Shape of pts2: (2, 778)
# Shape of pts1: (2, 893)
# Shape of pts2: (2, 893)
# Shape of pts1: (2, 1017)
# Shape of pts2: (2, 1017)
# Shape of pts1: (2, 1077)
# Shape of pts2: (2, 1077)
# Shape of pts1: (2, 1143)
# Shape of pts2: (2, 1143)
# Shape of pts1: (2, 1190)
# Shape of pts2: (2, 1190)
# Shape of pts1: (2, 1187)
# Shape of pts2: (2, 1187)
# Shape of pts1: (2, 1288)
# Shape of pts2: (2, 1288)
# Shape of pts1: (2, 1357)
# Shape of pts2: (2, 1357)
# Shape of pts1: (2, 1376)
# Shape of pts2: (2, 1376)
# Shape of pts1: (2, 1412)
# Shape of pts2: (2, 1412)
# Shape of pts1: (2, 1330)
# Shape of pts2: (2, 1330)
# Shape of pts1: (2, 1140)
# Shape of pts2: (2, 1140)
# Shape of pts1: (2, 1040)
# Shape of pts2: (2, 1040)
# Shape of pts1: (2, 1314)
# Shape of pts2: (2, 1314)
# Shape of pts1: (2, 1419)
# Shape of pts2: (2, 1419)
# Shape of pts1: (2, 1409)
# Shape of pts2: (2, 1409)
# Shape of pts1: (2, 1418)
# Shape of pts2: (2, 1418)
# Shape of pts1: (2, 1451)
# Shape of pts2: (2, 1451)
# Shape of pts1: (2, 1484)
# Shape of pts2: (2, 1484)
# Shape of pts1: (2, 1572)
# Shape of pts2: (2, 1572)
# Shape of pts1: (2, 1554)
# Shape of pts2: (2, 1554)
# Shape of pts1: (2, 1586)
# Shape of pts2: (2, 1586)
# Shape of pts1: (2, 1573)
# Shape of pts2: (2, 1573)
# Shape of pts1: (2, 1582)
# Shape of pts2: (2, 1582)
# Shape of pts1: (2, 1588)
# Shape of pts2: (2, 1588)
# Shape of pts1: (2, 1580)
# Shape of pts2: (2, 1580)
# Shape of pts1: (2, 1528)
# Shape of pts2: (2, 1528)
# Shape of pts1: (2, 1514)
# Shape of pts2: (2, 1514)
# Shape of pts1: (2, 1485)
# Shape of pts2: (2, 1485)
# Shape of pts1: (2, 1489)
# Shape of pts2: (2, 1489)
# Shape of pts1: (2, 1509)
# Shape of pts2: (2, 1509)
# Shape of pts1: (2, 1520)
# Shape of pts2: (2, 1520)
# Shape of pts1: (2, 1459)
# Shape of pts2: (2, 1459)
# Shape of pts1: (2, 1388)
# Shape of pts2: (2, 1388)
# Shape of pts1: (2, 1423)
# Shape of pts2: (2, 1423)
# Shape of pts1: (2, 1412)
# Shape of pts2: (2, 1412)
# Shape of pts1: (2, 1477)
# Shape of pts2: (2, 1477)
# Shape of pts1: (2, 1455)
# Shape of pts2: (2, 1455)
# Shape of pts1: (2, 1345)
# Shape of pts2: (2, 1345)
# Shape of pts1: (2, 1346)
# Shape of pts2: (2, 1346)
# Shape of pts1: (2, 1300)
# Shape of pts2: (2, 1300)
# Shape of pts1: (2, 1258)
# Shape of pts2: (2, 1258)
# Shape of pts1: (2, 1307)
# Shape of pts2: (2, 1307)
# Shape of pts1: (2, 1252)
# Shape of pts2: (2, 1252)
# Shape of pts1: (2, 1224)
# Shape of pts2: (2, 1224)
# Shape of pts1: (2, 1296)
# Shape of pts2: (2, 1296)
# Shape of pts1: (2, 1330)
# Shape of pts2: (2, 1330)
# Shape of pts1: (2, 1276)
# Shape of pts2: (2, 1276)
# Shape of pts1: (2, 1291)
# Shape of pts2: (2, 1291)
# Shape of pts1: (2, 1301)
# Shape of pts2: (2, 1301)
# Shape of pts1: (2, 1293)
# Shape of pts2: (2, 1293)
# Shape of pts1: (2, 1254)
# Shape of pts2: (2, 1254)
# Shape of pts1: (2, 1190)
# Shape of pts2: (2, 1190)
# Shape of pts1: (2, 1186)
# Shape of pts2: (2, 1186)
# Shape of pts1: (2, 1230)
# Shape of pts2: (2, 1230)
# Shape of pts1: (2, 1181)
# Shape of pts2: (2, 1181)
# Shape of pts1: (2, 1216)
# Shape of pts2: (2, 1216)
# Shape of pts1: (2, 1138)
# Shape of pts2: (2, 1138)
# Shape of pts1: (2, 1005)
# Shape of pts2: (2, 1005)
# Shape of pts1: (2, 1056)
# Shape of pts2: (2, 1056)
# Shape of pts1: (2, 1003)
# Shape of pts2: (2, 1003)
# Shape of pts1: (2, 893)
# Shape of pts2: (2, 893)
# Shape of pts1: (2, 719)
# Shape of pts2: (2, 719)
# Shape of pts1: (2, 649)
# Shape of pts2: (2, 649)
# Shape of pts1: (2, 734)
# Shape of pts2: (2, 734)
# Shape of pts1: (2, 744)
# Shape of pts2: (2, 744)
# Shape of pts1: (2, 768)
# Shape of pts2: (2, 768)
# Shape of pts1: (2, 812)
# Shape of pts2: (2, 812)
# Shape of pts1: (2, 904)
# Shape of pts2: (2, 904)
# Shape of pts1: (2, 983)
# Shape of pts2: (2, 983)
# Shape of pts1: (2, 980)
# Shape of pts2: (2, 980)
# Shape of pts1: (2, 947)
# Shape of pts2: (2, 947)
# Shape of pts1: (2, 1159)
# Shape of pts2: (2, 1159)
# Shape of pts1: (2, 1250)
# Shape of pts2: (2, 1250)
# Shape of pts1: (2, 1325)
# Shape of pts2: (2, 1325)
# Shape of pts1: (2, 1441)
# Shape of pts2: (2, 1441)
# Shape of pts1: (2, 1297)
# Shape of pts2: (2, 1297)
# Shape of pts1: (2, 1358)
# Shape of pts2: (2, 1358)
# Shape of pts1: (2, 1322)
# Shape of pts2: (2, 1322)
# Shape of pts1: (2, 1248)
# Shape of pts2: (2, 1248)
# Shape of pts1: (2, 1234)
# Shape of pts2: (2, 1234)
# Shape of pts1: (2, 1145)
# Shape of pts2: (2, 1145)
# Shape of pts1: (2, 1077)
# Shape of pts2: (2, 1077)
# Shape of pts1: (2, 957)
# Shape of pts2: (2, 957)
# Shape of pts1: (2, 948)
# Shape of pts2: (2, 948)
# Shape of pts1: (2, 848)
# Shape of pts2: (2, 848)
# Shape of pts1: (2, 744)
# Shape of pts2: (2, 744)
# Shape of pts1: (2, 742)
# Shape of pts2: (2, 742)
# Shape of pts1: (2, 667)
# Shape of pts2: (2, 667)
# Shape of pts1: (2, 679)
# Shape of pts2: (2, 679)
# Shape of pts1: (2, 681)
# Shape of pts2: (2, 681)
# Shape of pts1: (2, 663)
# Shape of pts2: (2, 663)
# Shape of pts1: (2, 662)
# Shape of pts2: (2, 662)
# Shape of pts1: (2, 643)
# Shape of pts2: (2, 643)
# Shape of pts1: (2, 579)
# Shape of pts2: (2, 579)
# Shape of pts1: (2, 509)
# Shape of pts2: (2, 509)
# Shape of pts1: (2, 502)
# Shape of pts2: (2, 502)
# Shape of pts1: (2, 605)
# Shape of pts2: (2, 605)
# Shape of pts1: (2, 680)
# Shape of pts2: (2, 680)
# Shape of pts1: (2, 665)
# Shape of pts2: (2, 665)
# Shape of pts1: (2, 619)
# Shape of pts2: (2, 619)
# Shape of pts1: (2, 597)
# Shape of pts2: (2, 597)
# Shape of pts1: (2, 615)
# Shape of pts2: (2, 615)
# Shape of pts1: (2, 676)
# Shape of pts2: (2, 676)
# Shape of pts1: (2, 663)
# Shape of pts2: (2, 663)
# Shape of pts1: (2, 619)
# Shape of pts2: (2, 619)
# Shape of pts1: (2, 657)
# Shape of pts2: (2, 657)
# Shape of pts1: (2, 650)
# Shape of pts2: (2, 650)
# Shape of pts1: (2, 640)
# Shape of pts2: (2, 640)
# Shape of pts1: (2, 726)
# Shape of pts2: (2, 726)
# Shape of pts1: (2, 685)
# Shape of pts2: (2, 685)
# Shape of pts1: (2, 573)
# Shape of pts2: (2, 573)
# Shape of pts1: (2, 451)
# Shape of pts2: (2, 451)
# Shape of pts1: (2, 427)
# Shape of pts2: (2, 427)
# Shape of pts1: (2, 374)
# Shape of pts2: (2, 374)
# Shape of pts1: (2, 397)
# Shape of pts2: (2, 397)
# Shape of pts1: (2, 423)
# Shape of pts2: (2, 423)
# Shape of pts1: (2, 458)
# Shape of pts2: (2, 458)
# Shape of pts1: (2, 391)
# Shape of pts2: (2, 391)
# Shape of pts1: (2, 373)
# Shape of pts2: (2, 373)
# Shape of pts1: (2, 319)
# Shape of pts2: (2, 319)
# Shape of pts1: (2, 321)
# Shape of pts2: (2, 321)
# Shape of pts1: (2, 354)
# Shape of pts2: (2, 354)
# Shape of pts1: (2, 346)
# Shape of pts2: (2, 346)
# Shape of pts1: (2, 351)
# Shape of pts2: (2, 351)
# Shape of pts1: (2, 327)
# Shape of pts2: (2, 327)
# Shape of pts1: (2, 342)
# Shape of pts2: (2, 342)
# Shape of pts1: (2, 336)
# Shape of pts2: (2, 336)
# Shape of pts1: (2, 360)
# Shape of pts2: (2, 360)
# Shape of pts1: (2, 386)
# Shape of pts2: (2, 386)
# Shape of pts1: (2, 399)
# Shape of pts2: (2, 399)
# Shape of pts1: (2, 405)
# Shape of pts2: (2, 405)
# Shape of pts1: (2, 432)
# Shape of pts2: (2, 432)
# Shape of pts1: (2, 464)
# Shape of pts2: (2, 464)
# Shape of pts1: (2, 473)
# Shape of pts2: (2, 473)
# Shape of pts1: (2, 495)
# Shape of pts2: (2, 495)
# Shape of pts1: (2, 524)
# Shape of pts2: (2, 524)
# Shape of pts1: (2, 500)
# Shape of pts2: (2, 500)
# Shape of pts1: (2, 524)
# Shape of pts2: (2, 524)
# Shape of pts1: (2, 500)
# Shape of pts2: (2, 500)
# Shape of pts1: (2, 469)
# Shape of pts2: (2, 469)
# Shape of pts1: (2, 458)
# Shape of pts2: (2, 458)
# Shape of pts1: (2, 457)
# Shape of pts2: (2, 457)
# Shape of pts1: (2, 463)
# Shape of pts2: (2, 463)
# Shape of pts1: (2, 472)
# Shape of pts2: (2, 472)
# Shape of pts1: (2, 438)
# Shape of pts2: (2, 438)
# Shape of pts1: (2, 383)
# Shape of pts2: (2, 383)
# Shape of pts1: (2, 275)
# Shape of pts2: (2, 275)
# Shape of pts1: (2, 171)
# Shape of pts2: (2, 171)
# Shape of pts1: (2, 154)
# Shape of pts2: (2, 154)
# Shape of pts1: (2, 128)
# Shape of pts2: (2, 128)
# Shape of pts1: (2, 123)
# Shape of pts2: (2, 123)
# Shape of pts1: (2, 98)
# Shape of pts2: (2, 98)
# Shape of pts1: (2, 89)
# Shape of pts2: (2, 89)
# Shape of pts1: (2, 70)
# Shape of pts2: (2, 70)
# Shape of pts1: (2, 56)
# Shape of pts2: (2, 56)
# Shape of pts1: (2, 71)
# Shape of pts2: (2, 71)
# Shape of pts1: (2, 72)
# Shape of pts2: (2, 72)
# Shape of pts1: (2, 68)
# Shape of pts2: (2, 68)
# Shape of pts1: (2, 64)
# Shape of pts2: (2, 64)
# Shape of pts1: (2, 62)
# Shape of pts2: (2, 62)
# Shape of pts1: (2, 48)
# Shape of pts2: (2, 48)
# Shape of pts1: (2, 52)
# Shape of pts2: (2, 52)
# Shape of pts1: (2, 49)
# Shape of pts2: (2, 49)
# Shape of pts1: (2, 43)
# Shape of pts2: (2, 43)
# Shape of pts1: (2, 39)
# Shape of pts2: (2, 39)
# Shape of pts1: (2, 35)
# Shape of pts2: (2, 35)
# Shape of pts1: (2, 27)
# Shape of pts2: (2, 27)
# Shape of pts1: (2, 18)
# Shape of pts2: (2, 18)
# Shape of pts1: (2, 13)
# Shape of pts2: (2, 13)
# Shape of pts1: (2, 5)
# Shape of pts2: (2, 5)
# Saved all 3D points to M11202130_stanta_colored_3d_points.txt
